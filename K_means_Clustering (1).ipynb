# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/Kmean_dataset.csv")
df
# Out:
#      feature0  feature1  feature2  feature3  feature4  feature5  feature6  \
# 0       14.23      1.71      2.43      15.6       127      2.80      3.06
# 1       13.20      1.78      2.14      11.2       100      2.65      2.76
# 2       13.16      2.36      2.67      18.6       101      2.80      3.24
# 3       14.37      1.95      2.50      16.8       113      3.85      3.49
# 4       13.24      2.59      2.87      21.0       118      2.80      2.69
# ..        ...       ...       ...       ...       ...       ...       ...
# 173     13.71      5.65      2.45      20.5        95      1.68      0.61
# 174     13.40      3.91      2.48      23.0       102      1.80      0.75
# 175     13.27      4.28      2.26      20.0       120      1.59      0.69
# 176     13.17      2.59      2.37      20.0       120      1.65      0.68
# 177     14.13      4.10      2.74      24.5        96      2.05      0.76
#
#      feature7  feature8  feature9  feature10  feature11  feature12
# 0        0.28      2.29      5.64       1.04       3.92       1065
# 1        0.26      1.28      4.38       1.05       3.40       1050
# 2        0.30      2.81      5.68       1.03       3.17       1185
# 3        0.24      2.18      7.80       0.86       3.45       1480
# 4        0.39      1.82      4.32       1.04       2.93        735
# ..        ...       ...       ...        ...        ...        ...
# 173      0.52      1.06      7.70       0.64       1.74        740
# 174      0.43      1.41      7.30       0.70       1.56        750
# 175      0.43      1.35     10.20       0.59       1.56        835
# 176      0.53      1.46      9.30       0.60       1.62        840
# 177      0.56      1.35      9.20       0.61       1.60        560
#
# [178 rows x 13 columns]

# %%
mean_normalized_data = (df - df.mean()) / (df.max() - df.min())
mean_normalized_data
# Out:
#      feature0  feature1  feature2  feature3  feature4  feature5  feature6  \
# 0    0.323522 -0.123784  0.033948 -0.200770  0.296287  0.174099  0.217454
# 1    0.052469 -0.109950 -0.121132 -0.427574  0.002809  0.122375  0.154163
# 2    0.041943  0.004674  0.162290 -0.046131  0.013679  0.174099  0.255428
# 3    0.360364 -0.076353  0.071381 -0.138915  0.144113  0.536168  0.308171
# 4    0.062995  0.050129  0.269242  0.077580  0.198461  0.174099  0.139395
# ..        ...       ...       ...       ...       ...       ...       ...
# 173  0.186679  0.654872  0.044643  0.051807 -0.051539 -0.212108 -0.299424
# 174  0.105101  0.310998  0.060686  0.180673  0.024548 -0.170728 -0.269888
# 175  0.070890  0.384121 -0.056961  0.026034  0.220200 -0.243142 -0.282546
# 176  0.044574  0.050129  0.001863  0.026034  0.220200 -0.222453 -0.284656
# 177  0.297206  0.348548  0.199724  0.257993 -0.040669 -0.084522 -0.267778
#
#      feature7  feature8  feature9  feature10  feature11  feature12
# 0   -0.154441  0.220537  0.049651   0.067114   0.479236   0.226895
# 1   -0.192177 -0.098075 -0.057857   0.075244   0.288760   0.216196
# 2   -0.116706  0.384574  0.053064   0.058984   0.204511   0.312487
# 3   -0.229913  0.185836  0.233951  -0.079227   0.307075   0.522901
# 4    0.053106  0.072272 -0.062977   0.067114   0.116599  -0.008483
# ..        ...       ...       ...        ...        ...        ...
# 173  0.298389 -0.167476  0.225419  -0.258089  -0.319299  -0.004917
# 174  0.128577 -0.057066  0.191289  -0.209308  -0.385233   0.002216
# 175  0.128577 -0.075993  0.438730  -0.298739  -0.385233   0.062844
# 176  0.317257 -0.041293  0.361938  -0.290609  -0.363255   0.066410
# 177  0.373861 -0.075993  0.353405  -0.282479  -0.370581  -0.133305
#
# [178 rows x 13 columns]

# %%
# Plot original train data
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.scatter(df['feature0'], df['feature1'])
plt.title('Original Data')
plt.xlabel('Feature0')
plt.ylabel('Feature1')

# Plot normalized train data
plt.subplot(1, 2, 2)
plt.scatter(mean_normalized_data['feature0'], mean_normalized_data['feature1'])
plt.title('Mean Normalized Data')
plt.xlabel('Feature0')
plt.ylabel('Feature1')

plt.tight_layout()
plt.show()

# %%
data=mean_normalized_data.values
data
# Out:
# array([[ 0.32352158, -0.12378425,  0.03394821, ...,  0.06711428,
#          0.47923612,  0.22689497],
#        [ 0.05246895, -0.10995026, -0.12113201, ...,  0.07524436,
#          0.28875993,  0.21619596],
#        [ 0.04194264,  0.00467425,  0.16229045, ...,  0.0589842 ,
#          0.20451084,  0.31248698],
#        ...,
#        [ 0.07089001,  0.38412089, -0.05696088, ..., -0.29873938,
#         -0.38523274,  0.06284361],
#        [ 0.04457422,  0.05012879,  0.00186264, ..., -0.2906093 ,
#         -0.36325472,  0.06640994],
#        [ 0.2972058 ,  0.34854776,  0.19972361, ..., -0.28247922,
#         -0.37058073, -0.13330475]])

# %%
def centroids_initialize(mean_normalized_data, k):
    centroids=mean_normalized_data.sample(k).values
    return centroids

# %%
def distance(x1,x2):
    distances=np.sqrt(np.sum((x1-x2)**2))
    return distances

# %%
def closest_centroid(data,centroids,k):
    centroids=centroids_initialize(mean_normalized_data, k)
    distances=np.empty(data.shape[0])
    for i in range(data.shape[0]):
        distances[i]=distance(data[i],centroids)
    return np.argmin(distances)

# %%
def label(data,centroids,k):
    centroids=centroids_initialize(mean_normalized_data, k)
    labels=np.empty(data.shape[0])
    for i in range(data.shape[0]):
        labels[i]=closest_centroid(data,centroids,k)
    return labels

# %%
def cal_new_centroids(data,labels,k):
    new_centroids=np.empty((k,data.shape[1]))
    for i in range(k):
        new_centroids[i]=np.mean(data[labels==i])
    return new_centroids

# %%
def K_means(data,k,iterations):
    centroids=centroids_initialize(mean_normalized_data, k)
    for i in range(iterations):
        labels=label(data,centroids,k)
        new_centroids=cal_new_centroids(data,labels,k)
        if np.array_equal(centroids,new_centroids):
            break
        centroids=new_centroids
    return labels,centroids

# %%
labels,centroids=K_means(data,k=5,iterations=100)
labels
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# array([ 81., 163., 168.,  88.,  65.,  32.,  35.,  81.,  62.,  37., 107.,
#         72.,  37.,  43.,  32.,  43., 117., 168.,  37.,  34.,  43.,  35.,
#         81.,  43.,  32.,  37.,  81.,  38.,  65.,  37.,  37.,  37.,  72.,
#        141.,  88.,  37., 148.,  32., 163.,  44., 161.,  62.,  43., 141.,
#         43.,  32.,  37.,  81.,  37.,   4.,  72., 139.,  37.,  81.,  65.,
#         35.,  37.,  34., 174.,  83.,  85.,  65.,  34., 161.,  37.,  35.,
#         37.,  81.,  35.,  81.,  23.,  43.,   4.,  43., 111.,  37., 141.,
#         62.,  34.,   4.,  38., 161.,  43.,  37.,  81., 174.,  26.,  34.,
#         35.,  37.,  65., 117., 107.,  65.,   4.,  37.,  37.,  43., 168.,
#         43.,  81.,  43.,  34.,  37., 168.,  34.,  37.,  34.,  32.,  35.,
#         43.,  38.,  37.,  34.,  38.,  43.,  34.,  43., 163., 174.,  35.,
#        107.,  81.,  81.,   4.,  35., 107.,  54.,  81., 168.,  43.,  36.,
#         34.,  65.,  37., 107.,  43.,  81.,   4.,   4.,   4.,  43.,  34.,
#         34., 141.,  32.,  37., 102.,  48.,  43.,  37.,  81., 174.,  81.,
#        111.,  37., 141., 107.,  88.,  37.,  43.,  34.,  48.,  81.,  34.,
#         37.,  81., 163.,  43.,  62.,  37.,  43.,   4., 106.,  81., 141.,
#         32.,  34.])

# %%
def wcss(labels,centroids,k):
    wcss_value=0
    for i in range(centroids.shape[0]):
        if np.sum(labels==i)>0:
            wcss_value+=np.sum(np.sum((data[labels==i]-centroids[i])**2))
    return wcss_value
k=range(1,11)
wcss_value=np.empty(10)
for i,k in enumerate(k):
    labels,centroids=K_means(data,k,iterations=100)
    wcss_value[i]=wcss(labels,centroids,k)
print(wcss_value)
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# [0.         1.59745354 0.         0.         8.08649066 3.64516477
#  3.02067625 2.66654892 9.09207299 5.17127831]

# %%
k=range(1,11)
plt.plot(k,wcss_value, marker='.')
plt.title("Elbow Graph")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.show()
